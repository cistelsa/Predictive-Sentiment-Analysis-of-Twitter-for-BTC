# %%
import pandas as pd
import openpyxl
import os
import re
import numpy as np

# %%
#El file name va a variar depende de la ubicación donde cada quien haya guardado el archivo
#pero la ruta que si debemos de tener todos en común es la siguiente:
#Predictive-Sentiment-Analysis-of-Twitter-for-BTC/Data_Analysis/Tableau_Practice/Data_Sets/wbb_rosters_2022_23.xlsx"
file_name = "C:/Users/willi/OneDrive/Escritorio/Henry/Proyecto twitter/Predictive-Sentiment-Analysis-of-Twitter-for-BTC/Data_Analysis/Tableau_Practice/Data_Sets/wbb_rosters_2022_23.xlsx"
file_path = os.path.join(os.getcwd(), file_name)
df= pd.read_excel(file_path, sheet_name="wbb_rosters_2022_23")

# %%
file_name = "/Users/luizacampos/Downloads/wbb_rosters_2022_23.xlsx"
file_path = os.path.join(os.getcwd(), file_name)
df= pd.read_excel(file_path, sheet_name="wbb_rosters_2022_23")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 file_name = "/Users/luizacampos/Downloads/wbb_rosters_2022_23.xlsx"
#       2 file_path = os.path.join(os.getcwd(), file_name)
# ----> 3 df= pd.read_excel(file_path, sheet_name="wbb_rosters_2022_23")
#
# File c:\Users\willi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\willi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\willi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:482, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, decimal, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     480 if not isinstance(io, ExcelFile):
#     481     should_close = True
# --> 482     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     483 elif engine and engine != io.engine:
#     484     raise ValueError(
#     485         "Engine should not be specified when passing "
#     486         "an ExcelFile - ExcelFile already has the engine set"
#     487     )
#
# File c:\Users\willi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1652, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1650     ext = "xls"
#    1651 else:
# -> 1652     ext = inspect_excel_format(
#    1653         content_or_path=path_or_buffer, storage_options=storage_options
#    1654     )
#    1655     if ext is None:
#    1656         raise ValueError(
#    1657             "Excel file format cannot be determined, you must specify "
#    1658             "an engine manually."
#    1659         )
#
# File c:\Users\willi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1525, in inspect_excel_format(content_or_path, storage_options)
#    1522 if isinstance(content_or_path, bytes):
#    1523     content_or_path = BytesIO(content_or_path)
# -> 1525 with get_handle(
#    1526     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1527 ) as handle:
#    1528     stream = handle.handle
#    1529     stream.seek(0)
#
# File c:\Users\willi\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:865, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#    (...)
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
# --> 865         handle = open(handle, ioargs.mode)
#     866     handles.append(handle)
#     868 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/Users/luizacampos/Downloads/wbb_rosters_2022_23.xlsx'

# %%
df.head()
# Out:
#    ncaa_id       team  player_id            name       year   hometown  \
# 0      721  Air Force    11807.0    Mackenzie Le   Freshman  Elk Grove
# 1      721  Air Force    11805.0  Milahnie Perry   Freshman      Tampa
# 2      721  Air Force    11801.0   Madison Smith  Sophomore    Connell
# 3      721  Air Force    11795.0    Taylor Britt     Junior   Columbia
# 4      721  Air Force    11796.0     Kamri Heath     Senior     Edmond
#
#         homestate                high_school previous_school_clean  \
# 0      California                St. Francis                   NaN
# 1         Florida  Seffner Christian Academy                   NaN
# 2      Washington                    Connell                   NaN
# 3  South Carolina              Spring Valley            USAFA Prep
# 4        Oklahoma               Edmond North                   NaN
#
#   height_clean  ... total_inches primary_position secondary_position  \
# 0         5'3"  ...         63.0            GUARD                NaN
# 1         5'7"  ...         67.0            GUARD                NaN
# 2         5'8"  ...         68.0            GUARD                NaN
# 3         5'7"  ...         67.0            GUARD                NaN
# 4         5'7"  ...         67.0            GUARD                NaN
#
#   position_clean year_clean redshirt                   hs_clean  \
# 0          GUARD   Freshman        0                St. Francis
# 1          GUARD   Freshman        0  Seffner Christian Academy
# 2          GUARD  Sophomore        0                    Connell
# 3          GUARD     Junior        0              Spring Valley
# 4          GUARD     Senior        0               Edmond North
#
#    hometown_clean  state_clean  country_clean
# 0   ELK GROVE, CA           CA            USA
# 1       TAMPA, FL           FL            USA
# 2     CONNELL, WA           WA            USA
# 3    COLUMBIA, SC           SC            USA
# 4      EDMOND, OK           OK            USA
#
# [5 rows x 29 columns]

# %% [markdown]
# Primero mostramos en pantalla todas las columnas que contiene el dataframe. Eso es importante pues, a depender de que informaciones queremos obtener de los datos, podremos eliminar algunas. En el caso de este trabajo, vamos a evaluar la altura promedio de las jugadoras, la relacion entre su altura y la posición en que juegan, que equipos poseen más jugadoras extranjeras.

# %%
print(df.columns)
# Out:
# Index(['ncaa_id', 'team', 'player_id', 'name', 'year', 'hometown', 'homestate',
#        'high_school', 'previous_school_clean', 'height_clean', 'position',
#        'jersey', 'url', 'season', 'team_state', 'conference', 'division',
#        'height_ft', 'height_in', 'total_inches', 'primary_position',
#        'secondary_position', 'position_clean', 'year_clean', 'redshirt',
#        'hs_clean', 'hometown_clean', 'state_clean', 'country_clean'],
#       dtype='object')

# %% [markdown]
# Pasamos a eliminar las columnas que no nos van a servir para el dashboard. Lo hicimos usando el metodo drop. Está por partes pues este método solo toma de 1 a 8 argumentos y queríamos eliminas muchas columnas.
# Vamos a mantener la columna "team", que indica el equipo en que juegan, "name" que nos trae como información el nombre de cada jugadora a la que nos referimos, "height_clean" que nos indica la altura de la jugadora, "position_clean" que nos indica que posición principal juega y "country_clean" que nos informa el país de origen.

# %%
df = df.drop(['ncaa_id','player_id', 'year', 'hometown', 'homestate',
       'high_school', 'previous_school_clean'], axis=1)

# %%
df = df.drop([ 'url', 'season', 'team_state', 'conference', 'division',
       'height_ft', 'height_in', 'total_inches'], axis = 1)

# %%
df = df.drop(['year_clean', 'redshirt', 'jersey',
       'hs_clean', 'hometown_clean', 'state_clean'], axis=1)

# %%
df = df.drop(['primary_position', 'secondary_position', 'position'], axis=1)

# %%
df.head()
# Out:
#         team            name height_clean position_clean country_clean
# 0  Air Force    Mackenzie Le         5'3"          GUARD           USA
# 1  Air Force  Milahnie Perry         5'7"          GUARD           USA
# 2  Air Force   Madison Smith         5'8"          GUARD           USA
# 3  Air Force    Taylor Britt         5'7"          GUARD           USA
# 4  Air Force     Kamri Heath         5'7"          GUARD           USA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13806 entries, 0 to 13805
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   team            13806 non-null  object
#  1   name            13806 non-null  object
#  2   height_clean    13767 non-null  object
#  3   position_clean  13774 non-null  object
#  4   country_clean   13806 non-null  object
# dtypes: object(5)
# memory usage: 539.4+ KB

# %% [markdown]
# En un segundo paso, averiguamos valores nulos. Lo vamos a hacer sumando la cantidad por columna e igualmente, averiguando el porcentaje de nulos en el dataframe

# %%
print(df.isnull().sum())
# Out:
# team               0
# name               0
# height_clean      39
# position_clean    32
# country_clean      0
# dtype: int64

# %%
print('% de registros con al menos un valor nulo: ', np.round(100 * df.isna().any(axis=1).sum() / df.shape[0], 1))
# Out:
# % de registros con al menos un valor nulo:  0.5

# %% [markdown]
# Como se puede observar, los valores nulos representan el 0,5% de los registros. El dataframe posee un total de 13807 filas y en las columnas que usaremos, el valor de nulos es de 39 para "height_clean" y 32 para "position_clean". Por ende, considerando el número muy pequeño que no afectarían nuestros resultados, optamos por borrar los nulos. Eliminaremos tambien los duplicados

# %%
df = df.drop_duplicates()

# %%
df = df.dropna(how='any')

# %%
df.dropna(subset=['height_clean'], inplace=True)

# %%
df.tail(50)
# Out:
#                  team                  name         height_clean  \
# 13754        Belhaven           Jayda Jones  2023-06-05 00:00:00
# 13755        Belhaven           Kourtne Lee  2023-08-05 00:00:00
# 13756        Belhaven          Jayda Duncan  2023-08-05 00:00:00
# 13757        Belhaven       Allaijah Gamble  2023-10-05 00:00:00
# 13758        Belhaven          Ebony Gayden  2023-10-05 00:00:00
# 13759        Belhaven      Hayle Poindexter  2023-02-06 00:00:00
# 13761        Belhaven        Ky'sha McNeely  2023-11-05 00:00:00
# 13763      SUNY Delhi           Aniya Jones                  5'7
# 13764      SUNY Delhi       Justine Lubbers                  5'9
# 13765      SUNY Delhi      Yasmeen Kablaoui                  5'2
# 13766      SUNY Delhi         Angelica Lazo                  5'0
# 13767      SUNY Delhi         Jenna Lubbers                  5'9
# 13768      SUNY Delhi        Juana Severino                  5'9
# 13769      SUNY Delhi        Myles Matthias                  5'5
# 13770      SUNY Delhi  Francesca Vassilakos                  5'7
# 13771      SUNY Delhi         Nicole Bryant                  5'5
# 13772      SUNY Delhi        Ma'Kira Busnie                  5'7
# 13773      SUNY Delhi           Jayda Allen                 5'11
# 13774      SUNY Delhi        Jahddah Lennon                  5'4
# 13775      SUNY Delhi         Hope Mulligan                  5'2
# 13776      SUNY Delhi           Leila Smith                  5'7
# 13777      SUNY Delhi        Rhys Flansburg                 5'11
# 13778  Centenary (LA)       Keyonna Armelin                  5-0
# 13779  Centenary (LA)         Amiyah Barrow  2023-04-05 00:00:00
# 13780  Centenary (LA)         Madison Davis                  5-0
# 13781  Centenary (LA)      Olivia Sepulvado  2023-05-05 00:00:00
# 13782  Centenary (LA)       TaNyjah Plumber  2023-05-05 00:00:00
# 13783  Centenary (LA)           Alana Jones  2023-10-05 00:00:00
# 13784  Centenary (LA)       Jillian Peacock  2023-07-05 00:00:00
# 13785  Centenary (LA)         Brailey Major  2023-05-05 00:00:00
# 13786  Centenary (LA)        Patience Bates  2023-07-05 00:00:00
# 13787  Centenary (LA)       Lauren Castillo  2023-01-05 00:00:00
# 13788  Centenary (LA)          Cairah Green                  5-0
# 13789  Centenary (LA)           Kyra Stokes  2023-11-05 00:00:00
# 13790  Centenary (LA)         Jazzmyn Jones  2023-09-05 00:00:00
# 13791  Centenary (LA)        Amelia Bagwell  2023-09-05 00:00:00
# 13792  Centenary (LA)          Dymon Drumgo  2023-08-05 00:00:00
# 13793   Bluefield St.              Rori Cox                 5'7"
# 13794   Bluefield St.       Azariah Binford                 5'4"
# 13795   Bluefield St.         Alexus Tucker                 5'8"
# 13796   Bluefield St.            Eriel West                 5'6"
# 13797   Bluefield St.         Katrina Davis                 5'4"
# 13798   Bluefield St.        Londen Coleman                 6'0"
# 13799   Bluefield St.          Aerihna Afoa                 5'6"
# 13800   Bluefield St.         Essence Cowan                 5'6"
# 13801   Bluefield St.     Derricka Bramwell                 6'0"
# 13802   Bluefield St.         Coraly Dupree                 6'1"
# 13803   Bluefield St.      Gabrielle Thomas                5'10"
# 13804   Bluefield St.       Zaynah Robinson                 5'4"
# 13805   Bluefield St.         Dani Janutolo                5'10"
#
#        position_clean country_clean
# 13754           GUARD           USA
# 13755           GUARD           USA
# 13756           GUARD           USA
# 13757           GUARD           USA
# 13758         FORWARD           USA
# 13759  FORWARD/CENTER           USA
# 13761  FORWARD/CENTER           USA
# 13763   GUARD/FORWARD           USA
# 13764         FORWARD           USA
# 13765           GUARD           USA
# 13766           GUARD           USA
# 13767         FORWARD           USA
# 13768  FORWARD/CENTER           USA
# 13769         FORWARD           USA
# 13770           GUARD           USA
# 13771         FORWARD           USA
# 13772           GUARD           USA
# 13773         FORWARD           USA
# 13774           GUARD           USA
# 13775           GUARD           USA
# 13776           GUARD           USA
# 13777         FORWARD           USA
# 13778           GUARD           USA
# 13779           GUARD           USA
# 13780           GUARD           USA
# 13781           GUARD           USA
# 13782           GUARD           USA
# 13783           GUARD           USA
# 13784           GUARD           USA
# 13785           GUARD           USA
# 13786           GUARD           USA
# 13787           GUARD           USA
# 13788           GUARD           USA
# 13789         FORWARD           USA
# 13790         FORWARD           USA
# 13791         FORWARD           USA
# 13792           GUARD           USA
# 13793           GUARD           USA
# 13794           GUARD           USA
# 13795           GUARD           USA
# 13796           GUARD           USA
# 13797           GUARD           USA
# 13798         FORWARD           USA
# 13799           GUARD           USA
# 13800           GUARD           USA
# 13801          CENTER           USA
# 13802          CENTER           USA
# 13803         FORWARD           USA
# 13804           GUARD           USA
# 13805           GUARD           USA

# %%
print(df.isna().sum())
# Out:
# team              0
# name              0
# height_clean      0
# position_clean    0
# country_clean     0
# dtype: int64

# %% [markdown]
# Si bien el dataframe ya no tiene nulos, evaluando el resultado, nos dimos cuenta que los datos cargados en la columna "height_clean" son de distintos tipos. Pasamos a averiguar

# %%
tipo_de_datos = df['height_clean'].dtype
print(tipo_de_datos)
# Out:
# object

# %%
#verificamos dato por dato, uno a uno, si todos son del tipo str y encontramos que algunos son del tipo "datetime"
tipo_de_datos = df['height_clean'].map(lambda x:type(x))
lista_tipo_de_datos = list(tipo_de_datos)
lista_tipo_de_datos [110:116] #para efectos practicos mandamos llamar los elementos del 110 al 116 para observar la diferencia
# Out:
# [str, str, str, datetime.datetime, datetime.datetime, datetime.datetime]

# %%
df.loc[116,'height_clean'] #el dato en el en la celda index 116 de la columna 'height_clean' es una fecha
# Out:
# datetime.datetime(2023, 6, 5, 0, 0)

# %%
df.iloc[110:116] #mejor visualización de los datos
# Out:
#                team             name         height_clean position_clean  \
# 110  Boston College      T'Yana Todd                 6'0"          GUARD
# 111  Boston College      Ally Carman                 6'5"         CENTER
# 112  Boston College    Akunna Konkwo                 6'2"         CENTER
# 113    Oregon State  Shalexxus Aaron  2023-01-06 00:00:00          GUARD
# 114    Oregon State     Bendu Yeaney  2023-10-05 00:00:00          GUARD
# 115    Oregon State    Lily Hansford  2023-02-06 00:00:00          GUARD
#
#     country_clean
# 110        CANADA
# 111           USA
# 112           USA
# 113           USA
# 114           USA
# 115           USA

# %%
#cambiamos a nulo los datos que sean del tipo date time
df['height_clean'] = df['height_clean'].apply(lambda x: None if isinstance(x, pd.datetime) else x)
# Out:
# C:\Users\willi\AppData\Local\Temp\ipykernel_14300\452767741.py:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   df['height_clean'] = df['height_clean'].apply(lambda x: None if isinstance(x, pd.datetime) else x)

# %%
df.iloc[110:116] # aquí ya podemos observar como los datos que solían ser fechas pasaron a None
# Out:
#                team             name height_clean position_clean country_clean
# 110  Boston College      T'Yana Todd         6'0"          GUARD        CANADA
# 111  Boston College      Ally Carman         6'5"         CENTER           USA
# 112  Boston College    Akunna Konkwo         6'2"         CENTER           USA
# 113    Oregon State  Shalexxus Aaron         None          GUARD           USA
# 114    Oregon State     Bendu Yeaney         None          GUARD           USA
# 115    Oregon State    Lily Hansford         None          GUARD           USA

# %%
#Volvemos a buscar los valores nulos del data frame pero lo pasamos a porcentaje
df.isnull().mean()*100   # como solo es el 17.5% de los datos decidimos borrarlos
# Out:
# team               0.000000
# name               0.000000
# height_clean      17.581138
# position_clean     0.000000
# country_clean      0.000000
# dtype: float64

# %%
df = df.dropna(subset=['height_clean'])  #eliminamos los valores null

# %%
df.isnull().mean()*100 #observamos que ya no tenemos valores nulos para columna 'height_clean'
# Out:
# team              0.0
# name              0.0
# height_clean      0.0
# position_clean    0.0
# country_clean     0.0
# dtype: float64

# %% [markdown]
# Usaremos una funcion para transformar los datos de la columna "height_clean". Esta función utiliza expresiones regulares para buscar patrones en las cadenas de altura y convertirlos a centímetros. Los patrones son los siguientes:
# feet_inches_pattern: busca un número seguido de un carácter que indica pies o pulgadas, luego otro número y otro carácter de pies o pulgadas. Ejemplos: "6'11", "5-8".
# feet_pattern: busca un número seguido de un carácter que indica pies. Ejemplo: "6'0".
# inches_pattern: busca un carácter que indica pulgadas seguido de un número. Ejemplo: "5'9".
# Si la cadena de entrada no coincide con ninguno de estos patrones, la función devuelve None.

# %%
def height_to_cm(height_str):
    feet_inches_pattern = re.compile(r'(\d+)([\W_])(\d+)')
    feet_pattern = re.compile(r'(\d+)([\W_])')
    inches_pattern = re.compile(r'([\W_])(\d+)')
    
    match = feet_inches_pattern.match(height_str)
    if match:
        feet = int(match.group(1))
        inches = int(match.group(3))
    else:
        match = feet_pattern.match(height_str)
        if match:
            feet = int(match.group(1))
            inches = 0
        else:
            match = inches_pattern.search(height_str)
            if match:
                feet = 0
                inches = int(match.group(2))
            else:
                return None
    
    total_inches = feet * 12 + inches
    height_cm = total_inches * 2.54
    return height_cm

# %%
df['height_clean'] = df['height_clean'].astype(str)

# %% [markdown]
# Vamos a crear una nueva columna llamando la función para transformar la data de height_clean a sistema métrico

# %%
df['height_cm'] = df['height_clean'].apply(height_to_cm)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11326 entries, 0 to 13805
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   team            11326 non-null  object
#  1   name            11326 non-null  object
#  2   height_clean    11326 non-null  object
#  3   position_clean  11326 non-null  object
#  4   country_clean   11326 non-null  object
#  5   height_cm       11326 non-null  float64
# dtypes: float64(1), object(5)
# memory usage: 619.4+ KB

# %%
df.head(5)
# Out:
#         team            name height_clean position_clean country_clean  \
# 0  Air Force    Mackenzie Le         5'3"          GUARD           USA
# 1  Air Force  Milahnie Perry         5'7"          GUARD           USA
# 2  Air Force   Madison Smith         5'8"          GUARD           USA
# 3  Air Force    Taylor Britt         5'7"          GUARD           USA
# 4  Air Force     Kamri Heath         5'7"          GUARD           USA
#
#    height_cm
# 0     160.02
# 1     170.18
# 2     172.72
# 3     170.18
# 4     170.18

# %%
#Vamos a obtner la altura promedio por equipo

# df_APE = df_Altura Promedio por Equipo
df_APE = df.groupby('team')   #agrupamos por "team"
df_APE = df_APE['height_cm'].mean()  #obtenemos la media por equipo
df_APE = df_APE.to_frame() #transformamos la serie a un dataframe
df_APE
# Out:
#                      height_cm
# team
# A&M-Corpus Christi  177.461333
# AUM                 172.950909
# Abilene Christian   177.409231
# Academy of Art      171.767500
# Adams St.           172.175714
# ...                        ...
# Xavier              180.702857
# Yale                181.065714
# York (PA)           182.880000
# Young Harris        174.283077
# Youngstown St.      182.880000
#
# [884 rows x 1 columns]

# %% [markdown]
# Finalmente, salvamos el archivo para usarlo en Tableau

# %%
df.to_excel(file_path, index=False)

# %%
#propongo guardar el excel con otro nombre ya que el data frame será exclusivamente para la altura promedio
df_APE.to_excel('Data_Sets/mean_height_data_frame.xlsx')

# %%
# como son cerca de 900 equipos escogemos a los 5 equipos con mayor altura promedio
df_APE_5 = df_APE['height_cm'].nlargest(5).to_frame()
df_APE_5
# Out:
#            height_cm
# team
# UConn     186.055000
# Michigan  185.589333
# Rutgers   184.785000
# Stanford  184.742667
# Kansas    184.573333

# %%
#propongo guardar el excel con otro nombre ya que el data frame será exclusivamente 
#para los 5 equipos con mayor altura promedio
df_APE_5.to_excel('Data_Sets/top5_mean_height_data_frame.xlsx')
