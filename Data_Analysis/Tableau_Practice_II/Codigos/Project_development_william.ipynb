# %%
import pandas as pd

# %%
# read the csv file and transform it into a data frame
df = pd.read_csv("C:/Users/willi/OneDrive/Escritorio/Henry/Proyecto twitter/Predictive-Sentiment-Analysis-of-Twitter-for-BTC/Data_Analysis/Tableau_Practice_II/Data_sets/supply_chain_data.csv")

# %%
#save data frame as a excel file
df.to_excel('C:/Users/willi/OneDrive/Escritorio/Henry/Proyecto twitter/Predictive-Sentiment-Analysis-of-Twitter-for-BTC/Data_Analysis/Tableau_Practice_II/Data_sets/supply_chain_data.xlsx')

# %%
# show the data frame just created
df.head(3)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# ...

# %%
Product_types = df['Product type'].unique()
Routes = df['Routes'].unique()
print(Product_types)
print(Routes)
# Out:
# ['haircare' 'skincare' 'cosmetics']
# ['Route B' 'Route C' 'Route A']

# %%
#show general information of the data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
# ...

# %%
#show stadistic info about the data frame
df.describe()
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# ...

# %% [markdown]
# Type of product with most manufacturing time

# %%
# group the data frame by product type and obtain higher Manufacturing lead time and the higher Manufacturing costs
type_product = df.groupby('Product type').agg({'Manufacturing lead time':sum, 'Manufacturing costs':sum}).sort_values('Manufacturing lead time', ascending=False)
type_product
# Out:
#               Manufacturing lead time  Manufacturing costs
# Product type
# haircare                          580          1647.571776
# skincare                          551          1959.726295
# cosmetics                         346          1119.371253

# %% [markdown]
# HAIRCARE is the product type with the longest manufacturing time

# %% [markdown]
# Look for the products that are above from mean manufacturing time

# %%
# PAMMT = products above mean manufacturing lead time
df_PAMMT = df[df['Manufacturing lead time']>14.77]
df_PAMMT.head(3)
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# ...

# %%
# show how many products from each type of product area above the mean
df_PAMMT = df_PAMMT.groupby('Product type').size()
df_PAMMT
# Out:
# Product type
# cosmetics     9
# haircare     22
# skincare     17
# dtype: int64

# %%
df_PAMMT.to_excel('C:/Users/willi/OneDrive/Escritorio/Henry/Proyecto twitter/Predictive-Sentiment-Analysis-of-Twitter-for-BTC/Data_Analysis/Tableau_Practice_II/Data_sets/product_type.xlsx')

# %% [markdown]
# HAIRCARE is the type of product with the highest quantity of products above the mean manufacturing time

# %% [markdown]
# Look for the top 5 manufacturing time products

# %%
df.sort_values('Manufacturing lead time', ascending=False).head(6)
# Out:
#    Product type    SKU      Price  Availability  Number of products sold  \
# 30     haircare  SKU30   8.022859            10                      327
# 1      skincare   SKU1  14.843523            95                      736
# 0      haircare   SKU0  69.808006            55                      802
# 92    cosmetics  SKU92  47.714233            44                      276
# 23    cosmetics  SKU23   4.324341            30                      391
# 54     haircare  SKU54  31.146243            11                      622
#
#     Revenue generated Customer demographics  Stock levels  Lead times  \
# 30        2766.342367                  Male            60          26
# 1         7460.900065                Female            53          30
# 0         8661.996792            Non-binary            58           7
# 92        2100.129755                  Male            90          25
# 23        8858.367571               Unknown            84           5
# ...

# %% [markdown]
# From the top 5 products, 3 belong to the HAIRCARE type product
