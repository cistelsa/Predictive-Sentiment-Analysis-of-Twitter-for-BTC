# %%
import tweepy
import pandas as pd

# %%
# Tokens de acceso
consumer_key = ''
consumer_secret = ''
access_token = ''
access_token_secret = ''

# %%
# Autenticación en la API de Twitter
auth = tweepy.OAuth1UserHandler(consumer_key, consumer_secret, access_token, access_token_secret)
api = tweepy.API(auth)

# %%
# Define las palabras clave relevantes para buscar los tweets
palabras_clave = ["bitcoin", "BTC", "$BTC"]

# %%
# Obtén tweets basados en las palabras clave
tweets = []
for palabra_clave in palabras_clave:
    for tweet in tweepy.Cursor(api.search_tweets, palabra_clave, count=100, tweet_mode='extended').items(1000):
        tweets.append(tweet)

# %%
# Almacena los tweets en un DataFrame de Pandas con las columnas solicitadas
tweets_df = pd.DataFrame(columns=['timestamp', 'user_id', 'screen_name', 'full_name', 'text', 'hashtags', 'mentions', 'retweet_count', 'favorite_count', 'tweet_sentiment'])

for tweet in tweets:
    timestamp = tweet.created_at
    user_id = tweet.user.id_str
    screen_name = tweet.user.screen_name
    full_name = tweet.user.name
    text = tweet.full_text
    hashtags = [tag['text'] for tag in tweet.entities['hashtags']]
    mentions = [mention['screen_name'] for mention in tweet.entities['user_mentions']]
    retweet_count = tweet.retweet_count
    favorite_count = tweet.favorite_count
    # Agrega la información de las columnas al DataFrame
    tweets_df = tweets_df.append({'timestamp': timestamp, 
                                  'user_id': user_id, 
                                  'screen_name': screen_name, 
                                  'full_name': full_name, 
                                  'text': text, 
                                  'hashtags': hashtags, 
                                  'mentions': mentions, 
                                  'retweet_count': retweet_count, 
                                  'favorite_count': favorite_count}, ignore_index=True)

# %%
# Ordena los tweets por fecha y resetea el índice
tweets_df = tweets_df.sort_values(by='timestamp').reset_index(drop=True)

# %%
# Visualiza el DataFrame resultante
tweets_df.sample(20)
# Out:
#                      timestamp              user_id      screen_name  \
# 1844 2023-05-13 04:24:17+00:00  1441935023091769349  BrunoNOUKPOZOU1
# 1170 2023-05-13 04:20:27+00:00            391761205   Edward20000817
# 1146 2023-05-13 04:20:20+00:00  1431811002698399744       evotek_eth
# 1113 2023-05-13 04:20:13+00:00  1467688508034666501         Fafnir_A
# 1242 2023-05-13 04:20:45+00:00  1614237294814167041      ozgurbey_23
# 1331 2023-05-13 04:21:04+00:00  1491430657939357699        HaChunhat
# 314  2023-05-13 04:16:48+00:00           1418733482       milansto81
# 605  2023-05-13 04:18:18+00:00            171597467       Vision8282
# 664  2023-05-13 04:18:30+00:00  1653289900567941122  officialbakaiti
# 305  2023-05-13 04:16:38+00:00  1623918071885840384       Imjustmeep
# 1600 2023-05-13 04:22:28+00:00  1603723000372932609     cashlezzrudy
# 35   2023-05-13 04:13:24+00:00  1640430725110415360      alanchesa95
# 1464 2023-05-13 04:21:38+00:00  1152903281837875201       btc_status
# 1163 2023-05-13 04:20:25+00:00  1648774964605251584   CollinsGle8943
# 1420 2023-05-13 04:21:25+00:00  1195932805835870208    mcdeltraverse
# 576  2023-05-13 04:18:09+00:00            445400928    niamh_hardy97
# 577  2023-05-13 04:18:09+00:00  1413819773352169476  chanTai52929144
# 723  2023-05-13 04:18:43+00:00            558092987       janerich97
# 1112 2023-05-13 04:20:13+00:00  1484589155325603840      Yakamasi890
# 877  2023-05-13 04:19:19+00:00   777421364588220416        sumit8676
#
#                                      full_name  \
# 1844                                 Bruno Ero
# 1170                          Edward Hsu (💙,🧡)
# 1146                                    EVOTEK
# 1113                              0xfafnir.eth
# 1242                                     Özgür
# 1331                                  Hasunday
# 314                                     M2TheS
# 605                                       Leon
# 664                                Nitin patil
# 305                                 ImJustMeep
# 1600                            Rudy Baldwin 🔮
# 35                                  Alan Chesa
# 1464                        BTC Status Alert 📊
# 1163                            Glenda Collins
# 1420                    McDeltron REKT Capital
# 576                                Niamh Hardy
# 577           chantaiman.⌐◨-◨.zks.arb.bnb🧙🏿‍♀️
# 723                                Jane Murphy
# 1112                                        こせ
# 877   sumit8676.wallet/.bit/.bnb/Avive Citizen
#
#                                                    text  \
# 1844  RT @ICamoletto: Zoom OUT - Constructive over y...
# 1170  RT @Ordiboys: TRVN 优势: \n\nTRVN创始人Trvon，是一位优秀的...
# 1146  RT @LilMoonLambo: The market is volatile right...
# 1113  RT @questify_gg: What happens if Steam and Twi...
# 1242  RT @via__trader: 24 Saat \n\n 300 TL #ödül 💸 \...
# 1331  RT @tuonglukim01: "Bitcoin is a meme" - @ryder...
# 314     RT @crypto_bitlord7: $MONG is the next #Bitcoin
# 605   RT @ZaleNFT: If you traded #Memecoins in the l...
# 664            What is Bitcoin? https://t.co/3UvyCsoeTJ
# 305   RT @girlgone_crypto: Another crazy week in the...
# 1600  RT @PasinoCom: 🚨 #GiveawayAlert 🚨\n\nWin a sha...
# 35    @RoobetES @alanchesa95 me llegó un bitcoin más...
# 1464  #BTC Derivs Sheet (Tweet every 15 min.)\nCME D...
# 1163           @kontiki2000 Have you heard of #bitcoin?
# 1420  @Breedlove22 @saylor #BRC20 #shitcoins on #bit...
# 576   RT @ZaleNFT: If you traded #Memecoins in the l...
# 577   RT @BtcMonkeSales: Bitcoin Monke #616 sold for...
# 723   RT @ZaleNFT: If you traded #Memecoins in the l...
# 1112  RT @Mami_2525z: 5/13 こんにちは❕\n\n⑴現金配布\n⑵PayPay\...
# 877   #Avive - Proof Of Networking Protocol\n\nJoin ...
#
#                                                hashtags  \
# 1844                                        [BTC, alts]
# 1170                                                 []
# 1146                                                 []
# 1113                                                 []
# 1242  [ödül, Crypto, bitcoin, dolar, gem, çekiliş, g...
# 1331                                                 []
# 314                                           [Bitcoin]
# 605                                         [Memecoins]
# 664                                                  []
# 305                                                  []
# 1600             [GiveawayAlert, BNB, Giveaway, Crypto]
# 35                                                   []
# 1464                                              [BTC]
# 1163                                          [bitcoin]
# 1420  [BRC20, shitcoins, bitcoin, shitscriptions, in...
# 576                                         [Memecoins]
# 577                                                  []
# 723                                         [Memecoins]
# 1112                                                 []
# 877                          [Avive, AviveCitizen, btc]
#
#                          mentions retweet_count favorite_count tweet_sentiment
# 1844                 [ICamoletto]             0              0             NaN
# 1170                   [Ordiboys]            10              0             NaN
# 1146               [LilMoonLambo]            76              0             NaN
# 1113     [questify_gg, SeiNetwok]          1270              0             NaN
# 1242                [via__trader]           217              0             NaN
# 1331  [tuonglukim01, ryder_ripps]           170              0             NaN
# 314             [crypto_bitlord7]           197              0             NaN
# 605                     [ZaleNFT]          4105              0             NaN
# 664                            []             0              0             NaN
# 305             [girlgone_crypto]            21              0             NaN
# 1600       [PasinoCom, PasinoCom]           246              0             NaN
# 35        [RoobetES, alanchesa95]             0              1             NaN
# 1464                           []             0              0             NaN
# 1163                [kontiki2000]             0              0             NaN
# 1420        [Breedlove22, saylor]             0              1             NaN
# 576                     [ZaleNFT]          4105              0             NaN
# 577               [BtcMonkeSales]             1              0             NaN
# 723                     [ZaleNFT]          4105              0             NaN
# 1112                 [Mami_2525z]            73              0             NaN
# 877                            []             0              0             NaN

# %%
tweets_df.shape
tweets_df.to_csv('tweets.csv', index=False)
